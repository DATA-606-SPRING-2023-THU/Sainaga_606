# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiNagaBandaru/Sainaga_606/blob/main/606_Final_Project_Capstone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import plotly.express as px
import matplotlib as plt
import seaborn as sns

import matplotlib.pyplot as plt
import numpy as np

# %%
train_df= pd.read_csv("/content/train_u6lujuX_CVtuZ9i.csv.xls")
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df.shape
# Out:
# (614, 13)

# %%
train_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
#checking for duplicate values
train_df.duplicated().sum()
# Out:
# 0

# %%
#checking for null values
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
mean = train_df['LoanAmount'].mean()
print(mean)
# Out:
# 146.41216216216216

# %%
train_df['LoanAmount'] = train_df['LoanAmount'].fillna(mean)

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df['Loan_Amount_Term']=train_df['Loan_Amount_Term'].fillna(train_df['Loan_Amount_Term'].mode()[0])

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df['Credit_History']=train_df['Credit_History'].fillna(train_df['Credit_History'].mode()[0])

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
test_df = pd.read_csv("/content/test_Y3wMUE5_7gLdaTN.csv.xls")
test_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
test_df.shape
# Out:
# (367, 12)

# %%
test_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
test_df.duplicated().sum()
# Out:
# 0

# %%
train_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
train_df1 = train_df.drop(['Loan_ID'],axis=1)
train_df1
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
#checking for the approval percent of loan status
train_df1['Loan_Status'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
#checking for the relation between the columns
#checking for unique values
#Visualizing unique values in columns
object = (train_df1.dtypes == 'object')
object_cols = list(object[object].index)
plt.figure(figsize=(40,60))
index = 1
  
for col in object_cols:
  y = train_df1[col].value_counts()
  plt.subplot(11,4,index)
  plt.xticks(rotation=90)
  sns.barplot(x=list(y.index), y=y)
  index +=1

# %% [markdown]
# #### Insights: About 80% applicants are male and married
# #### Fair chance of loan approval is more towards graduate and self- employed
# #### Semi Urban ares has more chance of loan approval

# %%
#Insights
plt.figure(1)
plt.subplot(131)
train_df1['Dependents'].value_counts(normalize=True).plot.bar(figsize=(12,3), title= 'Dependents')

plt.subplot(132)
train_df1['Education'].value_counts(normalize=True).plot.bar(title= 'Education')

plt.subplot(133)
train_df1['Property_Area'].value_counts(normalize=True).plot.bar(title= 'Property_Area')
# Out:
# <Axes: title={'center': 'Property_Area'}>

# %% [markdown]
# ###Less dependents
# ###Most of the applicants are graduates
# ###Most of the applicants are from semi urban area

# %% [markdown]
# ### Most of the applicants income ranges between 50,000-200,000$ and this applicant income column affects the loan amount.

# %%
# Checking the frequency distribution of numerial variable(Applicant Income)
sns.distplot(train_df['ApplicantIncome'])
plt.show()
train_df['ApplicantIncome'].plot.box(figsize=(16,5))
plt.show()
# Out:
# <ipython-input-100-55f189229c23>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['ApplicantIncome'])

# %%
# Checking the frequency distribution of numerial variable(CoApplicant Income)
sns.distplot(train_df['CoapplicantIncome'])
plt.show()
train_df['CoapplicantIncome'].plot.box(figsize=(16,5))
plt.show()
# Out:
# <ipython-input-101-6fea7dd2dd34>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['CoapplicantIncome'])

# %%
sns.distplot(train_df['LoanAmount'])
plt.show()
train_df['LoanAmount'].plot.box(figsize=(16,5))
plt.show()
# Out:
# <ipython-input-102-21aafc7a7006>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train_df['LoanAmount'])

# %%
sns.violinplot(data=train_df1, x="Loan_Status", y="ApplicantIncome")
# Out:
# <Axes: xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %% [markdown]
# ### Bivariate Analysis

# %%
#checking the behavior of each variable with respect to the target variable(Loan Status)
sns.countplot (data= train_df1, x='Loan_Status', hue= 'Gender')
plt.show()
sns.countplot (data= train_df1, x='Loan_Status', hue= 'Dependents')
plt.show()
sns.countplot (data= train_df1, x='Loan_Status', hue= 'Married')
plt.show()
sns.countplot (data= train_df1, x='Loan_Status', hue= 'Self_Employed')
plt.show()
sns.countplot (data= train_df1, x='Loan_Status', hue= 'Education')
plt.show()

# %% [markdown]
# ### Married Applicants has more chances of getting a loan

# %%
Credit=pd.crosstab(train_df1['Credit_History'],train_df['Loan_Status']) 
Credit.div(Credit.sum(1).astype(float),axis = 0).plot(kind="bar", figsize=(3,3)) 
plt.show() 
property = pd.crosstab(train_df1['Property_Area'],train_df['Loan_Status'])
property.div(property.sum(1).astype(float),axis = 0).plot(kind="bar", figsize=(3,3)) 
plt.show()

# %% [markdown]
#  ### Credit history with 1 has more chances of getting loan and likewise with the people from semi urban areas.
#
#  ##### Reference: https://medium.com/mlearning-ai/univariate-bivariate-and-multivariate-data-analysis-in-python-341493c3d173

# %%
# Visualize the correlation between columns
plt.figure(figsize=(12, 8))
sns.heatmap(train_df1.corr(), annot=True, cmap='YlGnBu')
plt.title('Feature Correlation')
plt.show()
# Out:
# <ipython-input-106-a5ddaf155e51>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(train_df1.corr(), annot=True, cmap='YlGnBu')

# %%
x= train_df.iloc[:,6:11].values

# %%
y= train_df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 0)

# %%
# fitting the logistic regression model

#Model_1 = np.linspace(0.001,2,100)
logit_model = LogisticRegression()
#print(df)
logit_model.fit(X_train,y_train)
#logit_model.C_
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix, precision_score, recall_score, precision_recall_curve,f1_score, roc_auc_score, roc_curve, log_loss,classification_report

# %%
y_pred = logit_model.predict(X_test)

# %%
#finding the accuracy
cm = confusion_matrix(y_test, y_pred)
acc_logit = accuracy_score(y_test, y_pred)
print(cm)
print(acc_logit)
# Out:
# [[15 18]
#  [ 2 88]]
# 0.8373983739837398

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
# Fitting K-NN to the Training set
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
#Confusion Matrix for KNN
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_KNN= accuracy_score(y_test, y_pred)
print(acc_KNN)
# Out:
# [[ 7 26]
#  [17 73]]
# 0.6504065040650406

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
# Fitting SVM to the Training set
from sklearn.svm import SVC
classifier_svm = SVC(kernel = 'linear', random_state = 0)
classifier_svm.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
#Confusion Matrix for SVM
y_pred = classifier_svm.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_SVM= accuracy_score(y_test, y_pred)
print(acc_SVM)
# Out:
# [[15 18]
#  [ 2 88]]
# 0.8373983739837398

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
# Fitting Naive Bayes to the Training set
from sklearn.naive_bayes import GaussianNB
classifier_NB = GaussianNB()
classifier_NB.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
#Confusion Matrix for NB
y_pred = classifier_NB.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_NB = accuracy_score(y_test, y_pred)
print(acc_NB)
# Out:
# [[15 18]
#  [ 3 87]]
# 0.8292682926829268

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
# Fitting Decision Tree Classification to the Training set
from sklearn.tree import DecisionTreeClassifier
classifier_tree = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#accuracy for decision tree model
y_pred = classifier_tree.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_tree = accuracy_score(y_test, y_pred)
print(acc_tree)
# Out:
# [[21 12]
#  [25 65]]
# 0.6991869918699187

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
#using label encoding to convert the categorical values to numerical values
from sklearn.preprocessing import LabelEncoder
labelencoder_y = LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 0)

# %%
from xgboost import XGBClassifier
classifier_XGB = XGBClassifier()
classifier_XGB.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
#finding the accuracy of the model
y_pred = classifier_XGB.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_XGB= accuracy_score(y_test, y_pred)
print(acc_XGB)
# Out:
# [[17 16]
#  [12 78]]
# 0.7723577235772358

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
#building random forest model
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_RF= RandomForestClassifier()
classifier_RF.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
#finding the accuracy of the model
y_pred = classifier_RF.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
print(cm)
acc_RF = accuracy_score(y_test, y_pred)
print(acc_RF)
# Out:
# [[17 16]
#  [10 80]]
# 0.7886178861788617

# %%
def show_classification_matrix(y_test, y_pred):

  sns.heatmap(cm, annot=True, fmt="0")
  ax = plt.gca()
  ax.set_xlabel("Predicted")
  ax.set_ylabel("Actual")

show_classification_matrix(y_train, y_pred)

# %%
#creating a dict
data_accuracies = {
    'Classifier': ['Logistic Regression','Random Forest','Decision Tree','Naive Bayes','XG Boost','KNN','SVM'], 
    'Accuracy_Score': [acc_logit,acc_RF, acc_tree, acc_NB,acc_XGB,acc_KNN,acc_SVM]
    }

print(data_accuracies)
# Out:
# {'Classifier': ['Logistic Regression', 'Random Forest', 'Decision Tree', 'Naive Bayes', 'XG Boost', 'KNN', 'SVM'], 'Accuracy_Score': [0.8373983739837398, 0.7886178861788617, 0.6991869918699187, 0.8292682926829268, 0.7723577235772358, 0.6504065040650406, 0.8373983739837398]}

# %%
#converting dictionary to a dataframe
df_scores = pd.DataFrame(data_accuracies)
df_scores
# Out:
#             Classifier  Accuracy_Score
# 0  Logistic Regression        0.837398
# 1        Random Forest        0.788618
# 2        Decision Tree        0.699187
# 3          Naive Bayes        0.829268
# 4             XG Boost        0.772358
# 5                  KNN        0.650407
# 6                  SVM        0.837398

# %%
#Visualize the distribution of accuacy scores
sns.barplot(data=df_scores, x='Classifier', y='Accuracy_Score')
plt.xticks(rotation=90)
plt.title('Accuracy Score Distribution')
plt.show()

# %% [markdown]
# ### Logistic Regression and SVM models worked best with 83.9% accuracies
